# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress, pearsonr

# %% [markdown]
# Read the dataset into pandas

# %%
d = pd.read_csv("~/Downloads/swiss.csv", index_col=0, sep=',')
d.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %% [markdown]
# Display each variable as a 1 dimensional histogram.

# %%
h = d.hist(bins=6, figsize=(12,12))

# %%
are these distributions independent?

# %%
import seaborn as sns
sns.heatmap(d.corr())
plt.show()

# %%
catholic = d.Catholic.values>50
x1 = d.Education.values[catholic]
y1 = d.Examination.values[catholic]
x2 = d.Education.values[~catholic]
y2 = d.Examination.values[~catholic]

# %%
plt.plot(x1, y1,'o',
        label='Catholic')
plt.plot(x2, y2,'o',
        label='Protestant')
plt.legend()
plt.xlabel('education')
plt.ylabel('examination')
plt.show()

# %%
x1 = d.Education.values[catholic]
y1 = d.Fertility.values[catholic]
x2 = d.Education.values[~catholic]
y2 = d.Fertility.values[~catholic]

# %%
plt.plot(x1, y1,'o',
        label='Catholic')
plt.plot(x2, y2,'o',
        label='Protestant')
plt.legend()
plt.xlabel('education')
plt.ylabel('Fertility')
plt.show()
